# %% [markdown]
# # Introduction sk-learn

# %% [markdown]
# <b>Iris dataset</b><br>
# reference : http://www.astro.washington.edu/users/vanderplas/Astr599/notebooks/17_SklearnIntro

# %% [markdown]
# ## Plot data points

# %%
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt

x_index = 2
y_index = 3

iris = load_iris()

# this formatter will label the colorbar with the correct target names
formatter = plt.FuncFormatter(lambda i, *args: iris.target_names[int(i)])


plt.scatter(iris.data[:, x_index], iris.data[:, y_index],c=iris.target)
plt.colorbar(ticks=[0, 1, 2], format=formatter)
plt.xlabel(iris.feature_names[x_index])
plt.ylabel(iris.feature_names[y_index]);

# %% [markdown]
# predict a data by training classifier

# %%
from sklearn import neighbors, datasets

iris = datasets.load_iris()
X, y = iris.data, iris.target

# create the model
knn = neighbors.KNeighborsClassifier(n_neighbors=1)

# fit the model
knn.fit(X, y)

# sepal: 3cm * 5cm, petal : 4cm * 2cm
# call the "predict" method:
result = knn.predict([[3, 5, 4, 2],])
result2 = knn.predict([[5, 1, 2, 2],])

print iris.target_names[result]
print iris.target_names[result2]
X
# Out:
# ['virginica']
# ['versicolor']
# /Library/Python/2.7/site-packages/PIL/Image.py:79: RuntimeWarning: The _imaging extension was built for another  version of Pillow or PIL
#   warnings.warn(str(v), RuntimeWarning)
# /Library/Python/2.7/site-packages/PIL/Image.py:79: RuntimeWarning: The _imaging extension was built for another  version of Pillow or PIL
#   warnings.warn(str(v), RuntimeWarning)
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.4,  3.9,  1.3,  0.4],
# ...
